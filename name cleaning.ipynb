# %%
import logging
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from scipy import stats
from statsmodels.tsa.api import VAR
from statsmodels.tools.eval_measures import rmse, aic
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.stattools import grangercausalitytests
import pickle
from sklearn.model_selection import train_test_split
import re
import logging

# %%
import plotly.express as px
df_aapl = pd.read_csv("df_aaple.csv")
df = df_aapl.iloc[:2000,:]

features = [n for n in list(df.columns) if n != "Date"]
features[:1]
for feature in features[:1]:
    result = adfuller(df[feature], autolag=None)
    counter = 0
    while result[1] > 0.05:
        feature_differenced = np.log(df[feature]) - np.log(df[feature].shift(1))
        na_count = feature_differenced.isna().sum()
        # If NA count is greater than 1 (1 is caused by shifiting the series) it is likely that original series contains 0s
        # Hence we add a constant to the series and only then apply log tranformations 
        if na_count > 1:
            feature_with_constant = df[feature] + 1
            feature_differenced = np.log(feature_with_constant) - np.log(feature_with_constant.shift(1))
        df[feature] = feature_differenced
    
px.line(df, x="Date", y="Close", title='Apple close price')
# Out:
# /home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/arraylike.py:397: RuntimeWarning:
#
# divide by zero encountered in log
#
# /home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/arraylike.py:397: RuntimeWarning:
#
# invalid value encountered in log
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/apoletaev/VSCodeProjects/Sun-2014/name cleaning.ipynb Cell 2' in <cell line: 7>()
#      <a href='vscode-notebook-cell:/home/apoletaev/VSCodeProjects/Sun-2014/name%20cleaning.ipynb#ch0000000?line=14'>15</a>         if na_count > 1:
#      <a href='vscode-notebook-cell:/home/apoletaev/VSCodeProjects/Sun-2014/name%20cleaning.ipynb#ch0000000?line=15'>16</a>             feature_with_constant = df[feature] + 1
# ---> <a href='vscode-notebook-cell:/home/apoletaev/VSCodeProjects/Sun-2014/name%20cleaning.ipynb#ch0000000?line=16'>17</a>             feature_differenced = np.log(feature_with_constant) - np.log(feature_with_constant.shift(1))
#      <a href='vscode-notebook-cell:/home/apoletaev/VSCodeProjects/Sun-2014/name%20cleaning.ipynb#ch0000000?line=17'>18</a>         df[feature] = feature_differenced
#      <a href='vscode-notebook-cell:/home/apoletaev/VSCodeProjects/Sun-2014/name%20cleaning.ipynb#ch0000000?line=19'>20</a> px.line(df, x="Date", y="Close", title='Apple close price')
#
# File ~/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py:5010, in Series.shift(self, periods, freq, axis, fill_value)
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=5007'>5008</a> @doc(NDFrame.shift, klass=_shared_doc_kwargs["klass"])  # type: ignore[has-type]
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=5008'>5009</a> def shift(self, periods=1, freq=None, axis=0, fill_value=None) -> Series:
# -> <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=5009'>5010</a>     return super().shift(
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=5010'>5011</a>         periods=periods, freq=freq, axis=axis, fill_value=fill_value
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=5011'>5012</a>     )
#
# File ~/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py:9466, in NDFrame.shift(self, periods, freq, axis, fill_value)
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=9461'>9462</a>     axis = self._get_axis_number(axis)
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=9462'>9463</a>     new_data = self._mgr.shift(
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=9463'>9464</a>         periods=periods, axis=axis, fill_value=fill_value
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=9464'>9465</a>     )
# -> <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=9465'>9466</a>     return self._constructor(new_data).__finalize__(self, method="shift")
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=9467'>9468</a> # when freq is given, index is shifted, data is not
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=9468'>9469</a> index = self._get_axis(axis)
#
# File ~/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py:345, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=342'>343</a>         object.__setattr__(self, "_name", name)
#     <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=343'>344</a>     else:
# --> <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=344'>345</a>         self.name = name
#     <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=345'>346</a>     return
#     <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=347'>348</a> # we are called internally, so short-circuit
#
# File ~/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py:5597, in NDFrame.__setattr__(self, name, value)
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=5594'>5595</a>     object.__setattr__(self, name, value)
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=5595'>5596</a> elif name in self._metadata:
# -> <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=5596'>5597</a>     object.__setattr__(self, name, value)
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=5597'>5598</a> else:
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/generic.py?line=5598'>5599</a>     try:
#
# File ~/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py:642, in Series.name(self, value)
#     <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=639'>640</a> @name.setter
#     <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=640'>641</a> def name(self, value: Hashable) -> None:
# --> <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=641'>642</a>     validate_all_hashable(value, error_name=f"{type(self).__name__}.name")
#     <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/series.py?line=642'>643</a>     object.__setattr__(self, "_name", value)
#
# File ~/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py:1740, in validate_all_hashable(error_name, *args)
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1720'>1721</a> def validate_all_hashable(*args, error_name: str | None = None) -> None:
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1721'>1722</a>     """
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1722'>1723</a>     Return None if all args are hashable, else raise a TypeError.
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1723'>1724</a>
#    (...)
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1737'>1738</a>     None
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1738'>1739</a>     """
# -> <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1739'>1740</a>     if not all(is_hashable(arg) for arg in args):
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1740'>1741</a>         if error_name:
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1741'>1742</a>             raise TypeError(f"{error_name} must be a hashable type")
#
# File ~/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py:1740, in <genexpr>(.0)
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1720'>1721</a> def validate_all_hashable(*args, error_name: str | None = None) -> None:
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1721'>1722</a>     """
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1722'>1723</a>     Return None if all args are hashable, else raise a TypeError.
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1723'>1724</a>
#    (...)
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1737'>1738</a>     None
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1738'>1739</a>     """
# -> <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1739'>1740</a>     if not all(is_hashable(arg) for arg in args):
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1740'>1741</a>         if error_name:
#    <a href='file:///home/apoletaev/miniconda3/envs/test1/lib/python3.10/site-packages/pandas/core/dtypes/common.py?line=1741'>1742</a>             raise TypeError(f"{error_name} must be a hashable type")
#
# KeyboardInterrupt:

# %%
df_aapl = pd.read_csv("df_aaple.csv")
df = df_aapl.iloc[:4300,:]

feature_differenced = np.log(df["Close"]) - np.log(df["Close"].shift(1))
df["Close"] = feature_differenced
px.line(df, x="Date", y="Close", title='Apple close price')
